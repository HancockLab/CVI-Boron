# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
import scipy.stats as stats
import os
from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
from matplotlib.ticker import MaxNLocator
import matplotlib.ticker as ticker
from matplotlib import gridspec
from scipy import stats

# %%
df=pd.read_table('FigS9.txt')
df
# Out:
#       AccessionName  Accession_ID  Surroundingcoverage  Windowcoverage  \
# 0            F1-201          3968            12.860213       17.101124
# 1            F1-201          3968            12.860213       23.574282
# 2            F1-201          3968            12.860213       27.770287
# 3            F1-201          3968            12.860213       25.595506
# 4            F1-201          3968            12.860213       28.189763
# ...             ...           ...                  ...             ...
# 17703          F9-3         22644            19.376874       22.912609
# 17704          F9-3         22644            19.376874       21.285893
# 17705          F9-3         22644            19.376874       20.332085
# 17706          F9-3         22644            19.376874       18.353308
# 17707          F9-3         22644            19.376874       20.363296
#
#          TDcopy
# 0      1.329770
# 1      1.833118
# 2      2.159396
# 3      1.990286
# 4      2.192014
# ...

# %%
fig, ax=plt.subplots(1,1,figsize=(6,30))
Order= df.groupby('AccessionName').TDcopy.median().sort_values()
sns.boxplot(data=df,
            x='TDcopy',
            y='AccessionName',
            color='grey',
            order=Order.index)
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
plt.grid(color='0',axis = 'x',linestyle='--')
plt.xlabel('$\itBOR1$ copy number',fontsize=14)
plt.ylabel('')
# plt.savefig("FigS9.png", format="png",bbox_inches="tight",facecolor='w',dpi=400)
# Out:
# Text(0, 0.5, '')
